# %%
# %matplotlib inline
from sympy import *
from sympy.abc import a, b, c, t, x, y, z, sigma, omega, phi, psi, zeta, theta
init_printing()

# %%
x0 = symbols('x_0')
integrate(Eq(diff(x(t) ,t), 1 / x**5), )

#integrate(1 / x**5,x)
# Out:
#        -1
# x(t) = ────
#           4
#        4⋅x

# %%
1/x**5
# Out:
# 1
# ──
#  5
# x

# %%
dsolve(diff(x(t), t) - x(t)**5, ics={x(0): x0})
# Out:
# ⎡            __________             __________                __________
# ⎢           ╱   -1                 ╱   -1                    ╱   -1
# ⎢x(t) = -4 ╱  ──────── , x(t) = 4 ╱  ──────── , x(t) = -ⅈ⋅4 ╱  ──────── , x(t)
# ⎣        ╲╱   C₁ + 4⋅t          ╲╱   C₁ + 4⋅t             ╲╱   C₁ + 4⋅t
#
#          __________⎤
#         ╱   -1     ⎥
#  = ⅈ⋅4 ╱  ──────── ⎥
#      ╲╱   C₁ + 4⋅t ⎦

# %%
dsolve(diff(x(t), t) - x(t), ics={x(x0): x0})
# Out:
#            t
# x(t) = C₁⋅ℯ

# %% [markdown]
# ### Question 2

# %%
eqns2 = [Eq(x(t).diff(t), -x(t)-2*y(t)), Eq(y(t).diff(t), x(t)+y(t))]
eqns2
# Out:
# ⎡d                          d                     ⎤
# ⎢──(x(t)) = -x(t) - 2⋅y(t), ──(y(t)) = x(t) + y(t)⎥
# ⎣dt                         dt                    ⎦

# %%
soln2=dsolve(eqns2)
soln2
# Out:
# [x(t) = -2⋅C₁⋅sin(t) - 2⋅C₂⋅cos(t), y(t) = (C₁ - C₂)⋅sin(t) + (C₁ + C₂)⋅cos(t)
# ]

# %%
# Out:
#   File "<ipython-input-11-40c3e11bc0c8>", line 1
#     Eq(diff(z(t),t) = )
#                       ^
# SyntaxError: invalid syntax

# %%
z = symbols('z', real=False)
Eq(diff(z(t),t), (a+I*b)*z(t) - z(t)*absolute(z(t))**2 )
# Out:
# /usr/local/lib/python2.7/dist-packages/IPython/core/formatters.py:239: FormatterWarning: Exception in image/png formatter:
# \frac{d}{d t} z{\left (t \right )} = \left(a + i b\right) z{\left (t \right )} - z{\left (t \right )} \left\lvert{z{\left (t \right )}}\right\rvert^{2}
#                                                                                                            ^
# Expected a delimiter (at char 107), (line:1, col:108)
#   FormatterWarning,
# d                                      2
# ──(z(t)) = (a + ⅈ⋅b)⋅z(t) - z(t)⋅│z(t)│
# dt

# %%
[x,y] = np.meshgrid(np.linspace(-10,10), np.linspace(-10,10))
u = -x-2*y
v = x + y
plt.figure(figsize=(16,16))
plt.streamplot(x,y,u,v)

# %%
y
# Out:
# array([[-10.        , -10.        , -10.        , ..., -10.        ,
#         -10.        , -10.        ],
#        [ -9.59183673,  -9.59183673,  -9.59183673, ...,  -9.59183673,
#          -9.59183673,  -9.59183673],
#        [ -9.18367347,  -9.18367347,  -9.18367347, ...,  -9.18367347,
#          -9.18367347,  -9.18367347],
#        ...,
#        [  9.18367347,   9.18367347,   9.18367347, ...,   9.18367347,
#           9.18367347,   9.18367347],
#        [  9.59183673,   9.59183673,   9.59183673, ...,   9.59183673,
#           9.59183673,   9.59183673],
#        [ 10.        ,  10.        ,  10.        , ...,  10.        ,
#          10.        ,  10.        ]])
